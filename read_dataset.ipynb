# %% [markdown]
# ## Reading COVIDx Dataset

# %%
import os
import torch
import pandas as pd
from skimage import io, transform
import numpy as np
print(np.version.version)

import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

import covidx
# Out:
# 1.18.1

# %%
# configure paths
txt_file = '../COVID-Net/train_split_v2.txt'
images_path = '../covid-chestxray-dataset/data/train'

# %%
training_dataset = covidx.COVIDxDataset(txt_file, images_path)

def show_image(image, label):
    """Show image with landmarks"""
    plt.imshow(image, cmap = 'gray')
    #plt.scatter(landmarks[:, 0], landmarks[:, 1], s=10, marker='.', c='r')
    plt.pause(0.001)  # pause a bit so that plots are updated

# %%
print(len(training_dataset))
# Out:
# 16575

# %%
fig = plt.figure()

for i in range(len(training_dataset)):
    sample = training_dataset[i]

    print(i, sample['image'].shape, sample['label'])

    ax = plt.subplot(1, 4, i + 1)
    plt.tight_layout()
    ax.set_title('Sample #{}'.format(i))
    ax.axis('off')
    show_image(**sample)

    if i == 3:
        plt.show()
        break
# Out:
# 0 (1546, 1800) pneumonia
# 1 (1546, 1800) pneumonia
# 2 (1800, 1772) pneumonia
# 3 (1710, 1708) pneumonia
